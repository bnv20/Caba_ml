# %% [markdown]
# [과제]
#
# FIFA 데이터셋인 data.csv를 db에 임포트한 후 db와 연결하여 데이터프레임으로 가져오세요.

# %%
import cx_Oracle
import pandas as pd
db = cx_Oracle.connect("CABA_PDB","CABA","localhost:1521/xepdb1")
cursor = db.cursor()
cursor.execute("select * from FIFA")
x = cursor.fetchall()
df = pd.DataFrame(x)
cursor.execute("select column_name from user_tab_columns where table_name='FIFA'")
col = cursor.fetchall()
list1 = []
for i in col:
    for j in i:
        list1.append(j)
df.columns = list1
df.head()
# Out:
#        ID          NAME  AGE                                           PHOTO  \
# 0  198710  J. Rodríguez   26  https://cdn.sofifa.org/players/4/19/198710.png
# 1  198219    L. Insigne   27  https://cdn.sofifa.org/players/4/19/198219.png
# 2  197781          Isco   26  https://cdn.sofifa.org/players/4/19/197781.png
# 3  190460    C. Eriksen   26  https://cdn.sofifa.org/players/4/19/190460.png
# 4  189242      Coutinho   26  https://cdn.sofifa.org/players/4/19/189242.png
#
#   NATIONALITY                                 FLAG  OVERALL  POTENTIAL  \
# 0    Colombia  https://cdn.sofifa.org/flags/56.png       88         89
# 1       Italy  https://cdn.sofifa.org/flags/27.png       88         88
# 2       Spain  https://cdn.sofifa.org/flags/45.png       88         91
# 3     Denmark  https://cdn.sofifa.org/flags/13.png       88         91
# 4      Brazil  https://cdn.sofifa.org/flags/54.png       88         89
#
#                 CLUB                                     CLUB_LOGO  ...  \
# ...
